# %%
#!pip install opencv-python

# %%
import cv2
import numpy
import matplotlib.pyplot as plt

# %%
image=cv2.imread(r"C:\\Users\Student\Desktop\pic\pic1.jpg")

# %%
cv2.imshow("pic",image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (174, 290, 3)

# %%
print("height",image.shape[0])
print("width",image.shape[1])
# Out:
# height 174
# width 290

# %%
cv2.imwrite("output.jpg",image)
# Out:
# True

# %%
plt.imshow(image)

# %%
plt.imshow(image[...,::-1])

# %%
rgbimage=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(rgbimage)

# %%
cv2.COLOR_BGR2RGB
# Out:
# 4

# %%
rgbimage=cv2.cvtColor(image,4)
plt.imshow(rgbimage)

# %%
B,G,R=image[10,50]
print(B,G,R)
# Out:
# 237 178 99

# %%
grayimage=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
grayimage[10,50]
# Out:
# 161

# %%
#R*0.2989+G*0.5870+B*0.1140

# %%
grayimage=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2.imshow("gray",grayimage)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(grayimage,cmap="gray")

# %%
image=cv2.imread(r"C:\\Users\Student\Desktop\pic\pic1.jpg")
image[40:140,100:300,:]=(255,20,200)
plt.imshow(image[...,::-1])

# %%
image=cv2.imread(r"C:\\Users\Student\Desktop\pic\pic1.jpg")
cropped=image[60:130,120:250]
plt.imshow(cropped[...,::-1])

# %%
height,width=image.shape[:2]
crop=image[height//3:3*height//4,width//3:3*width//4]
plt.imshow(crop[...,::-1])
