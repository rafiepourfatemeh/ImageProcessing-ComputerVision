# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %%
img=cv2.imread(r"C:\\Users\Student\Desktop\pic07\sudoko.jpg")

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edges=cv2.Canny(gray,80,150)
lines=cv2.HoughLines(edges,1,np.pi/180,120)
for line in lines:
    rho,theta=line[0]
    a=np.cos(theta)
    b=np.sin(theta)
    x0=a*rho
    y0=b*rho
    x1=int(x0+1000*(-b))
    y1=int(y0+1000*(a))
    x2=int(x0-1000*(-b))
    y2=int(y0-1000*(a))
    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)
plt.imshow(img[...,::-1])
plt.show()

# %%
original_img=cv2.imread(r"C:\\Users\Student\Desktop\pic07\highway-lanes.jpg")
img=original_img.copy()
blured=cv2.GaussianBlur(original_img,(5,5),0)
gray=cv2.cvtColor(blured,cv2.COLOR_BGR2GRAY)
edges=cv2.Canny(gray,50,150)
lines=cv2.HoughLinesP(edges,1,np.pi/180,50,minLineLength=20,maxLineGap=50)
for line in lines:
    x1,y1,x2,y2=line[0]
    
    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)
plt.imshow(img[...,::-1])
plt.show()

# %%
original_img=cv2.imread(r"C:\\Users\Student\Desktop\pic07\s.png")
gray=cv2.cvtColor(original_img,cv2.COLOR_BGR2GRAY)
gray=cv2.medianBlur(gray,5)
rows=gray.shape[0]
circles=cv2.HoughCircles(gray,cv2.HOUGH_GRADIENT,1,rows/8,param1=200,param2=30)
if circles is not None:
    circles=np.uint16(np.around(circles))
    for c in circles[0,:]:
        center_x,center_y,radius=c
        center=(center_x,center_y)
        cv2.circle(original_img,center,radius,(255,0,255),3)
plt.imshow(original_img[...,::-1])
plt.show()

# %%
original_img=cv2.imread(r"C:\\Users\Student\Desktop\pic07\c3.jpeg")
gray=cv2.cvtColor(original_img,cv2.COLOR_BGR2GRAY)
gray=cv2.medianBlur(gray,5)
rows=gray.shape[0]
circles=cv2.HoughCircles(gray,cv2.HOUGH_GRADIENT,1,rows/8,param1=100,param2=30)
if circles is not None:
    circles=np.uint16(np.around(circles))
    for c in circles[0,:]:
        center_x,center_y,radius=c
        center=(center_x,center_y)
        cv2.circle(original_img,center,radius,(255,0,255),3)
plt.imshow(original_img[...,::-1])
plt.show()

# %%
len(circles[0])
# Out:
# 8

# %%
original_img=cv2.imread(r"C:\\Users\Student\Desktop\pic07\y2.jpg")
gray=cv2.cvtColor(original_img,cv2.COLOR_BGR2GRAY)
gray=cv2.medianBlur(gray,5)
rows=gray.shape[0]
circles=cv2.HoughCircles(gray,cv2.HOUGH_GRADIENT,1,rows/8,param1=100,param2=30,minRadius=50,maxRadius=100)
if circles is not None:
    circles=np.uint16(np.around(circles))
    for c in circles[0,:]:
        center_x,center_y,radius=c
        center=(center_x,center_y)
        cv2.circle(original_img,center,radius,(255,0,255),10)
plt.imshow(original_img[...,::-1])
plt.show()
print(f"count={len(circles[0])}")
# Out:
# count=20
