# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
image=cv2.imread(r"C:\\Users\Student\Desktop\pic\01.jpg")
height,width=image.shape[:2]
#height,width,ch=image.shape

# %%
t=np.float32([[0.5,0,0],[0,0.5,0]])
img_resize=cv2.warpAffine(image,t,(width//2,height//2))

# %%
plt.figure(figsize=[12,7])
plt.subplot(121);plt.imshow(image[...,::-1]);plt.title("image")
plt.subplot(122);plt.imshow(img_resize[...,::-1]);plt.title("resized")
plt.show()

# %%
rotation=10
theta=rotation*np.pi/180
t1=np.float32([[np.cos(theta),-np.sin(theta)],[np.sin(theta),np.cos(theta)]])
t2=np.float32([[0.5,0],[0,0.5]])
t=np.matmul(t1,t2)
final_t=np.zeros((2,3))
final_t[:,:-1]=t
print(final_t)
# Out:
# [[ 0.49240386 -0.08682409  0.        ]
#  [ 0.08682409  0.49240386  0.        ]]

# %%
result=cv2.warpAffine(image,final_t,(width,height))
plt.figure(figsize=[12,7])
plt.subplot(121);plt.imshow(image[...,::-1]);plt.title("image")
plt.subplot(122);plt.imshow(result[...,::-1]);plt.title("resized")
plt.show()

# %%
image=cv2.imread(r"C:\\Users\Student\Desktop\pic\03.jpeg")
cv2.imshow("original image",image)
cv2.waitKey()
image_scale=cv2.resize(image,None,fx=0.75,fy=0.75)
cv2.imshow("scale 3/4",image_scale)
cv2.waitKey()
image_scale=cv2.resize(image,None,fx=2,fy=2,interpolation=cv2.INTER_CUBIC)
cv2.imshow("scale 2",image_scale)
cv2.waitKey()
image_scale=cv2.resize(image,(900,400),interpolation=cv2.INTER_AREA)
cv2.imshow("scale special",image_scale)
cv2.waitKey()
cv2.destroyAllWindows()
